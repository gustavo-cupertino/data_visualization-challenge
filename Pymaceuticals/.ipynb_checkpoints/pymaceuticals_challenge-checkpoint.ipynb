# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# dependencies 

import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# %%
# import and read data

Mouse_metadata_df = pd.read_csv("../Pymaceuticals/data/Mouse_metadata.csv")

Study_results_df = pd.read_csv("../Pymaceuticals/data/Study_results.csv")

# %%
Mouse_metadata_df.head()
# Out:
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0     k403     Ramicane    Male          21          16
# 1     s185    Capomulin  Female           3          17
# 2     x401    Capomulin  Female          16          15
# 3     m601    Capomulin    Male          22          17
# 4     g791     Ramicane    Male          11          16

# %%
Study_results_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
# Combine data into a single dataset 

dataset = pd.merge(Study_results_df, Mouse_metadata_df, on="Mouse ID")

dataset.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0           45.000000                 0    Capomulin
# 1     b128          5           45.651331                 0    Capomulin
# 2     b128         10           43.270852                 0    Capomulin
# 3     b128         15           43.784893                 0    Capomulin
# 4     b128         20           42.731552                 0    Capomulin
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1  Female           9          22
# 2  Female           9          22
# 3  Female           9          22
# 4  Female           9          22

# %%
# checking the number of mices

mices_count = dataset["Mouse ID"].unique()
mices_count = pd.Series(mices_count).count()
mices_count
# Out:
# 249

# %%
# getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint.

duplicate = dataset.loc[(dataset[["Timepoint","Mouse ID"]].duplicated()), :]["Mouse ID"]
duplicate
# Out:
# 861    g989
# 863    g989
# 865    g989
# 867    g989
# 869    g989
# Name: Mouse ID, dtype: object

# %%
# getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint.

duplicate = dataset.loc[(dataset[["Timepoint","Mouse ID"]].duplicated()), :]["Mouse ID"]
duplicate
# Out:
# 861    g989
# 863    g989
# 865    g989
# 867    g989
# 869    g989
# Name: Mouse ID, dtype: object

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

new_dataset = dataset.set_index(["Mouse ID"])
new_dataset = new_dataset.drop(index="g989")
new_dataset = new_dataset.reset_index()
new_dataset
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1875     m601         25           33.118756                 1    Capomulin
# 1876     m601         30           31.758275                 1    Capomulin
# 1877     m601         35           30.834357                 1    Capomulin
# 1878     m601         40           31.378045                 1    Capomulin
# 1879     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# 0     Female           9          22
# 1     Female           9          22
# 2     Female           9          22
# 3     Female           9          22
# 4     Female           9          22
# ...      ...         ...         ...
# 1875    Male          22          17
# 1876    Male          22          17
# 1877    Male          22          17
# 1878    Male          22          17
# 1879    Male          22          17
#
# [1880 rows x 8 columns]

# %%
# Checking the number of mice in the clean DataFrame.

mice_check = new_dataset["Mouse ID"].unique()
mice_check = pd.Series(mice_check).count()
mice_check
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
summary = pd.DataFrame()

# %%
summary["Mean Tumor Volume"] = new_dataset[["Tumor Volume (mm3)","Drug Regimen"]].groupby("Drug Regimen").mean()
summary["Median Tumor Volume"] = new_dataset[["Tumor Volume (mm3)","Drug Regimen"]].groupby("Drug Regimen").median()
summary["Tumor Volume Variance"] = new_dataset[["Tumor Volume (mm3)","Drug Regimen"]].groupby("Drug Regimen").var()
summary["Tumor Volume Std. Dev."] = new_dataset[["Tumor Volume (mm3)","Drug Regimen"]].groupby("Drug Regimen").std()
summary["Tumor Volume Std. Err."] = new_dataset[["Tumor Volume (mm3)","Drug Regimen"]].groupby("Drug Regimen").sem()

# %%
summary_stat = summary[["Mean Tumor Volume","Median Tumor Volume","Tumor Volume Variance","Tumor Volume Std. Dev.","Tumor Volume Std. Err."]]
summary_stat
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# Capomulin                   4.994774                0.329346
# Ceftamin                    6.268188                0.469821
# Infubinol                   6.567243                0.492236
# Ketapril                    8.279709                0.603860
# Naftisol                    8.134708                0.596466
# Placebo                     7.821003                0.581331
# Propriva                    6.622085                0.544332
# Ramicane                    4.846308                0.320955
# Stelasyn                    7.710419                0.573111
# Zoniferol                   6.966589                0.516398
